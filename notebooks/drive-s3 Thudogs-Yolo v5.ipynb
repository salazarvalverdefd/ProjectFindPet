# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install awscli
# Out:
# ...
#      |████████████████████████████████| 1.5 MB 7.7 MB/s
# ...
#      |████████████████████████████████| 7.7 MB 47.4 MB/s
# ...
#      |████████████████████████████████| 547 kB 36.3 MB/s
# ...
#      |████████████████████████████████| 79 kB 6.4 MB/s
# ...
#      |████████████████████████████████| 138 kB 60.1 MB/s
# ...
#   Created wheel for awscli: filename=awscli-1.20.3-py3-none-any.whl size=3627125 sha256=b24f4a38d848baed4dfd8204b601ffb1b63550a25a5dd7c491bc761a8e6eabad
#   Stored in directory: /root/.cache/pip/wheels/cc/d8/12/c0e9fbe8c6e17a1c5d8e56cbe3ad211d401b4bfdbbdd6fc038
# Successfully built awscli
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.17.1
#     Uninstalling docutils-0.17.1:
#       Successfully uninstalled docutils-0.17.1
# ...

# %%
# !aws configure

# %%
# !aws s3 cp /content/drive/MyDrive/Project\ FindPet/dataset/ThudogsDataset/original/low-resolution s3://find-pet-bucket/dataset/ThudogsDataset/original/low-resolution --recursive --include "*"
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# upload: drive/MyDrive/Project FindPet/dataset/ThudogsDataset/original/low-resolution/7449-n000128-teddy/n165758.jpeg to s3://find-pet-bucket/dataset/ThudogsDataset/original/low-resolution/7449-n000128-teddy/n165758.jpeg
# upload: drive/MyDrive/Project FindPet/dataset/ThudogsDataset/original/low-resolution/7449-n000128-teddy/n165759.jpeg to s3://find-pet-bucket/dataset/ThudogsDataset/original/low-resolution/7449-n000128-teddy/n165759.jpeg
# upload: drive/MyDrive/Project FindPet/dataset/ThudogsDataset/original/low-resolution/7449-n000128-teddy/n165760.jpeg to s3://find-pet-bucket/dataset/ThudogsDataset/original/low-resolution/7449-n000128-teddy/n165760.jpeg
# upload: drive/MyDrive/Project FindPet/dataset/ThudogsDataset/original/low-resolution/7449-n000128-teddy/n165757.jpeg to s3://find-pet-bucket/dataset/ThudogsDataset/original/low-resolution/7449-n000128-teddy/n165757.jpeg
# ...

# %%
# !aws s3 cp /content/drive/MyDrive/Project\ FindPet/dataset/ThudogsDataset/original/Low-Annotations s3://find-pet-bucket/dataset/ThudogsDataset/original/Low-annotations --recursive --include "*"
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# upload: drive/MyDrive/Project FindPet/dataset/ThudogsDataset/original/Low-Annotations/7449-n000128-teddy/n165749.jpeg.xml to s3://find-pet-bucket/dataset/ThudogsDataset/original/Low-annotations/7449-n000128-teddy/n165749.jpeg.xml
# upload: drive/MyDrive/Project FindPet/dataset/ThudogsDataset/original/Low-Annotations/7449-n000128-teddy/n165750.jpeg.xml to s3://find-pet-bucket/dataset/ThudogsDataset/original/Low-annotations/7449-n000128-teddy/n165750.jpeg.xml
# upload: drive/MyDrive/Project FindPet/dataset/ThudogsDataset/original/Low-Annotations/7449-n000128-teddy/n165751.jpeg.xml to s3://find-pet-bucket/dataset/ThudogsDataset/original/Low-annotations/7449-n000128-teddy/n165751.jpeg.xml
# upload: drive/MyDrive/Project FindPet/dataset/ThudogsDataset/original/Low-Annotations/7449-n000128-teddy/n165762.jpeg.xml to s3://find-pet-bucket/dataset/ThudogsDataset/original/Low-annotations/7449-n000128-teddy/n165762.jpeg.xml
# ...

# %%
# !aws s3 cp s3://find-pet-bucket/dataset/ThudogsDataset/yolov5 /content/drive/MyDrive/SaturdaysAI/yolov5 --recursive --include "*"
# Out:
# download: s3://find-pet-bucket/dataset/ThudogsDataset/yolov5/.dockerignore to drive/MyDrive/SaturdaysAI/yolov5/.dockerignore
# download: s3://find-pet-bucket/dataset/ThudogsDataset/yolov5/.git/HEAD to drive/MyDrive/SaturdaysAI/yolov5/.git/HEAD
# download: s3://find-pet-bucket/dataset/ThudogsDataset/yolov5/.git/description to drive/MyDrive/SaturdaysAI/yolov5/.git/description
# download: s3://find-pet-bucket/dataset/ThudogsDataset/yolov5/.git/FETCH_HEAD to drive/MyDrive/SaturdaysAI/yolov5/.git/FETCH_HEAD
# download: s3://find-pet-bucket/dataset/ThudogsDataset/yolov5/.git/hooks/commit-msg.sample to drive/MyDrive/SaturdaysAI/yolov5/.git/hooks/commit-msg.sample
# download: s3://find-pet-bucket/dataset/ThudogsDataset/yolov5/.git/config to drive/MyDrive/SaturdaysAI/yolov5/.git/config
# download: s3://find-pet-bucket/dataset/ThudogsDataset/yolov5/.git/hooks/fsmonitor-watchman.sample to drive/MyDrive/SaturdaysAI/yolov5/.git/hooks/fsmonitor-watchman.sample
# ...
