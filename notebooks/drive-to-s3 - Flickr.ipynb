# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install awscli
# Out:
# ...
#      |████████████████████████████████| 3.6MB 8.9MB/s
# ...
#      |████████████████████████████████| 81kB 8.9MB/s
# ...
#      |████████████████████████████████| 7.9MB 38.4MB/s
# ...
#      |████████████████████████████████| 552kB 34.0MB/s
# ...
#      |████████████████████████████████| 143kB 57.7MB/s
# ...
#   Created wheel for botocore: filename=botocore-1.20.111-py2.py3-none-any.whl size=7695032 sha256=aaa8d4b8ab0322efda83eb2ac5dd3c731302323c24898fa1c58c790a834fbdf2
#   Stored in directory: /root/.cache/pip/wheels/1e/5f/dd/9021b3f78dc76c95f97ea9cd1798aa6da9bc1a61fe7d1bb9fa
# Successfully built botocore
# ERROR: requests 2.23.0 has requirement urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you'll have urllib3 1.26.6 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ...
#   Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ...

# %%
# !aws configure

# %%
# !aws s3 cp /content/drive/MyDrive/Project\ FindPet/dataset/FlickrDogDataset/original/Flickr-dog/ s3://findpet-datasets/flickrdog/original --recursive --include "*"
# Out:
# upload: drive/MyDrive/Project FindPet/dataset/FlickrDogDataset/original/Flickr-dog/Apolo/Apolo__09-crp.png to s3://findpet-datasets/flickrdog/original/Apolo/Apolo__09-crp.png
# upload: drive/MyDrive/Project FindPet/dataset/FlickrDogDataset/original/Flickr-dog/Apolo/Apolo__01-crp.png to s3://findpet-datasets/flickrdog/original/Apolo/Apolo__01-crp.png
# upload: drive/MyDrive/Project FindPet/dataset/FlickrDogDataset/original/Flickr-dog/Apolo/Apolo__03-crp.png to s3://findpet-datasets/flickrdog/original/Apolo/Apolo__03-crp.png
# upload: drive/MyDrive/Project FindPet/dataset/FlickrDogDataset/original/Flickr-dog/Apolo/Apolo__07-crp.png to s3://findpet-datasets/flickrdog/original/Apolo/Apolo__07-crp.png
# upload: drive/MyDrive/Project FindPet/dataset/FlickrDogDataset/original/Flickr-dog/Apolo/Apolo__04-crp.png to s3://findpet-datasets/flickrdog/original/Apolo/Apolo__04-crp.png
# ...

# %%
import os

path = "/content/drive/MyDrive/Project FindPet/dataset/FlickrDogDataset/original/Flickr-dog/"
print('number of folders:', len(os.listdir(path)))
# Out:
# number of dogs: 42

# %%
# !aws s3 cp /content/drive/MyDrive/Project\ FindPet/dataset/StanfordDataset/data/ s3://findpet-datasets/stanford/data --recursive --include "*"
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# upload: drive/MyDrive/Project FindPet/dataset/StanfordDataset/data/n02108089-boxer/n02108089_11807.jpg to s3://findpet-datasets/stanford/data/n02108089-boxer/n02108089_11807.jpg
# upload: drive/MyDrive/Project FindPet/dataset/StanfordDataset/data/n02108089-boxer/n02108089_11616.jpg to s3://findpet-datasets/stanford/data/n02108089-boxer/n02108089_11616.jpg
# upload: drive/MyDrive/Project FindPet/dataset/StanfordDataset/data/n02108089-boxer/n02108089_11875.jpg to s3://findpet-datasets/stanford/data/n02108089-boxer/n02108089_11875.jpg
# upload: drive/MyDrive/Project FindPet/dataset/StanfordDataset/data/n02108089-boxer/n02108089_117.jpg to s3://findpet-datasets/stanford/data/n02108089-boxer/n02108089_117.jpg
# upload: drive/MyDrive/Project FindPet/dataset/StanfordDataset/data/n02108089-boxer/n02108089_122.jpg to s3://findpet-datasets/stanford/data/n02108089-boxer/n02108089_122.jpg
# ...

# %%
# !pip install boto3
# Out:
# ...
#      |████████████████████████████████| 133kB 9.0MB/s
# ...

# %%
from boto3 import client
conn = client('s3', aws_access_key_id='AKIAWJBJOMAB4E6TEJJM', aws_secret_access_key='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')  # again assumes boto.cfg setup, assume AWS S3
for key in conn.list_objects(Bucket='findpet-datasets')['Contents']:
    print(key['Key'])
# Out:
# flickrdog/
# flickrdog/original/
# flickrdog/original/Apolo/Apolo__01-crp.png
# flickrdog/original/Apolo/Apolo__02-crp.png
# flickrdog/original/Apolo/Apolo__03-crp.png
# flickrdog/original/Apolo/Apolo__04-crp.png
# flickrdog/original/Apolo/Apolo__05-crp.png
# flickrdog/original/Apolo/Apolo__06-crp.png
# flickrdog/original/Apolo/Apolo__07-crp.png
# flickrdog/original/Apolo/Apolo__08-crp.png
# flickrdog/original/Apolo/Apolo__09-crp.png
# flickrdog/original/Apolo/Apolo__10-crp.png
# flickrdog/original/Apolo/Apolo__11-crp.png
# flickrdog/original/Apolo/Apolo__12-crp.png
# flickrdog/original/Bailey/Bailey__01-crp.png
# flickrdog/original/Bailey/Bailey__02-crp.png
# flickrdog/original/Bailey/Bailey__03-crp.png
# flickrdog/original/Bailey/Bailey__04-crp.png
# flickrdog/original/Bailey/Bailey__05-crp.png
# flickrdog/original/Bandit/Bandit__01-crp.png
# flickrdog/original/Bandit/Bandit__02-crp.png
# flickrdog/original/Bandit/Bandit__03-crp.png
# flickrdog/original/Bandit/Bandit__04-crp.png
# ...

# %%
breed_list = []
for prefix in conn.list_objects(Bucket='findpet-datasets', Prefix= 'flickrdog/original/', Delimiter='/')['CommonPrefixes']:
  breed_list.append(prefix['Prefix'].split('/')[2])
  #print(prefix['Prefix'])

# %%
breed_list
# Out:
# ['Apolo',
#  'Bailey',
#  'Bandit',
#  'Bella-Kappel',
#  'Bella-Theresa',
#  'Bella',
#  'Bu-chan',
#  'Chloe',
#  'Clara',
#  'Cody',
#  'Dakota-CNC',
#  'Dakota',
#  'Doris',
#  'Duke',
#  'Eve',
#  'Gracie',
#  'Injun',
#  'Kira',
#  'Koda',
#  'Landy',
#  'Lulu',
#  'Meeshka',
#  'Monty',
#  'Newton',
#  'Nikita',
#  'Noodles',
#  'Oliver',
#  'Peaches',
#  'Princesa',
#  'Purcy',
#  'Rave',
#  'Rico',
#  'Ridley',
#  'Roscoe',
#  'Skipper',
#  'Skye',
#  'Tala',
#  'Wilco',
#  'Winston',
#  'Yoda',
#  'Zeus-Rekel',
#  'Zowie']

# %%
path_img = []
for key in conn.list_objects(Bucket='findpet-datasets', Prefix= 'flickrdog/')['Contents']:    
    if (len(key['Key']) > 19):
      path_img.append(key['Key'])

# %%
path_img
# Out:
# ['flickrdog/original/Apolo/Apolo__01-crp.png',
#  'flickrdog/original/Apolo/Apolo__02-crp.png',
#  'flickrdog/original/Apolo/Apolo__03-crp.png',
#  'flickrdog/original/Apolo/Apolo__04-crp.png',
#  'flickrdog/original/Apolo/Apolo__05-crp.png',
#  'flickrdog/original/Apolo/Apolo__06-crp.png',
#  'flickrdog/original/Apolo/Apolo__07-crp.png',
#  'flickrdog/original/Apolo/Apolo__08-crp.png',
#  'flickrdog/original/Apolo/Apolo__09-crp.png',
#  'flickrdog/original/Apolo/Apolo__10-crp.png',
#  'flickrdog/original/Apolo/Apolo__11-crp.png',
#  'flickrdog/original/Apolo/Apolo__12-crp.png',
#  'flickrdog/original/Bailey/Bailey__01-crp.png',
#  'flickrdog/original/Bailey/Bailey__02-crp.png',
#  'flickrdog/original/Bailey/Bailey__03-crp.png',
#  'flickrdog/original/Bailey/Bailey__04-crp.png',
#  'flickrdog/original/Bailey/Bailey__05-crp.png',
#  'flickrdog/original/Bandit/Bandit__01-crp.png',
#  'flickrdog/original/Bandit/Bandit__02-crp.png',
#  'flickrdog/original/Bandit/Bandit__03-crp.png',
# ...

# %%
import cv2
import numpy as np
from PIL import Image
from matplotlib import pyplot as plt

# %%
import boto3
from PIL import Image
from io import BytesIO
import os

# %%
file_byte_string = conn.get_object(Bucket='findpet-datasets', Key='flickrdog/original/Apolo/Apolo__01-crp.png')['Body'].read()
Image.open(BytesIO(file_byte_string))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=250x250 at 0x7F1B6B8F5E50>
