# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
# path
path = '/content/drive/MyDrive/Ciclos/21/Project FindPet/dataset/ThudogsDataset/original/low-resolution/1043-n000001-Shiba_Dog/n100015.jpeg'

# Using cv2.imread() method
img = cv2.imread(path)
#print(img)
print(img.shape)
#cv2_imshow(img)
imgplot = plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
# Out:
# (500, 374, 3)

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import glob,os

def read_label(image_path):
  file_name = image_path.replace('.jpg', '.txt')
  with open(file_name, 'rt') as file:
    print(os.path.basename(file_name) + ': \n' + file.read())
path = '/content/drive/MyDrive/Ciclos/21/Project FindPet/dataset/ThudogsDataset/original/low-resolution/1043-n000001-Shiba_Dog/*.jpg'
image_path = glob.glob(path)
fig = plt.figure(figsize=(12,8))
cols = 2
rows = 2
grid = gridspec.GridSpec(nrows=rows, ncols=cols, figure=fig)
for i in range(cols*rows):
  fig.add_subplot(grid[i])
  image=plt.imread(image_path[i])
  plt.title(os.path.basename(image_path[i]))
  plt.axis(False)
  plt.imshow(image)
  #read_label(image_path[i])

#plt.savefig("dataset_examples.jpg", dpi=300)

# %%
# !python --version
# Out:
# Python 3.7.10
